# %%
import dill as dl
import pandas as pd

# %%
path=r'D:\OneDrive - Northwestern University\PycharmProjects\Speech\main\data\AA\AA_auditory_naming_df.pkl'
with open(path, 'rb') as f:
    df = dl.load(f)

# %%
df
# Out:
#     session                                            hg_data  trial_onset  \
# 0         0  [[14.961863253903948, 15.011588987362533, 14.6...          1.0
# 1         0  [[-0.07764328785207021, -0.03597921198533125, ...          1.0
# 2         0  [[0.25566905785138644, 0.20202561721074266, 0....          1.0
# 3         0  [[-0.3434942622550038, -0.3304044684155747, -0...          1.0
# 4         0  [[0.3553997330547744, 0.286151891327937, 0.203...          1.0
# 5         0  [[-0.3007240226278789, -0.3160387859224957, -0...          1.0
# 6         0  [[-0.3584048780639331, -0.3769951536731752, -0...          1.0
# 7         0  [[0.1932554801899619, 0.1538125841516976, 0.10...          1.0
# 8         0  [[-0.20268256034332596, -0.2242794072472964, -...          1.0
# 9         0  [[-0.3215654886482882, -0.37205642321012283, -...          1.0
# 10        0  [[-0.12257249147521446, -0.1773299414259789, -...          1.0
# ...

# %%
df['hg_data'][0].shape
# Out:
# (97, 12300)

# %%
binned_data=df['binned_data_reduced']
binned_data.shape
# Out:
# (53, 96, 87)

# %%
event_times_relative=df['event_times_relative']
event_times_relative
# Out:
# {'aud stim onset': (-1.6522641509433962, 0.41598549280507263),
#  'aud stim midpoint': (0.0, 0.0),
#  'aud stim offset': (1.6522641509433962, 0.41598549280507263),
#  'go cue onset': (5.153962264150943, 1.0566435639407996),
#  'voice onset': (5.856165018867924, 1.0539218104196193),
#  'voice offset': (6.721081735849056, 1.0828773189354197)}

# %%
path=r"D:\OneDrive - Northwestern University\PycharmProjects\Speech\main\data\AA\AA_auditory_naming_labels.pkl"
with open(path, 'rb') as f:
    labels = dl.load(f)
labels.keys()
# Out:
# Index(['target_word', 'answered_word', 'target_lexeme', 'answered_lexeme',
#        'class', 'class_idx', 'answered_lexeme_idx', 'homophone_target',
#        'homophone_answer', 'correct_response'],
#       dtype='object')

# %%
path=r"D:\OneDrive - Northwestern University\PycharmProjects\Speech\main\data\AA\AA_picture_naming_channels.pkl"
with open(path, 'rb') as f:
    labels = dl.load(f)
labels.keys()
# Out:
# Index(['channel_name', 'rois', 'primary_roi', 'LE', 'SA', 'clean'], dtype='object')
